# %% [markdown]
# ### Упражнение 1.1
#
# Найдите значение 0.1-квантиля для следующих данных: 26, 27, 29, 30, 32, 33, 34, 35, 36, 36, 37, 37, 38, 38, 39, 41, 42, 44, 45, 47.
#
# Ответ: 27
#
# ### Упражнение 1.2
#
# Найдите значение 0.2-квантиля для тех же данных.
# Ответ: 30
#
# ### Упражнение 1.3
#
# Найдите значение 0.9-квантиля для тех же данных.
#
# Ответ: 44
#
# ### Упражнение 2
#
# Найдите 0.48-квантиль для зефирного набора: 26, 27, 29, 30, 32, 33, 34, 35, 36, 36, 37, 37, 38, 38, 39, 41, 42, 44, 45, 47.
#
# Ответ: 36
#
# ### Упражнение 3
#
# Расставьте значения по возрастанию. Соедините понятие с его порядковым номером в полученном отсортированном наборе.
#
# ![Описание изображения](https://sun9-77.userapi.com/impg/IHWIxn6Hbo4rq2GiCOWNP4olXw3mWBaQ_BT0hw/d--4o6JE0k8.jpg?size=747x768&quality=95&sign=7be22a0479c18bebe64d7a22af4a69b8&type=album)
#
#
# ### Упражнение 4.1
#
# Небольшой магазин «Ручки-попрыгучки» продаёт канцелярские принадлежности. Последние 20 дней владелец магазина анализирует ежедневное количество посетителей, чтобы определить дни аномально низкой или высокой посещаемости. Он собрал данные и отсортировал их по возрастанию: 42, 45, 47, 49, 52, 54, 55, 58, 60, 62, 65, 67, 68, 70, 71, 74, 77, 80, 92, 115.
#
# Q1 = 52
#
# Q3 = 71
#
# IQR = Q3 − Q1 = 71 − 52 = 19.
#
# Определите границы для расчёта выбросов.
# В ответ введите два числа через пробел: сначала нижнюю границу, затем верхнюю. Дробные числа запишите в десятичном формате через точку.
# Ответ: 23.5 и 99.5
#
# ### Упражнение 4.2
#
# Посчитайте количество выбросов в данных.
#
# Ответ: 1
#
# ### Упражнение 5
#
# Соотнесите номер и название элемента диаграммы.
#
# ![Описание изображения](https://pictures.s3.yandex.net/resources/boxplot_5_1685970421.png)
#
# 1 - граница правого уса
#
# 2 - первый квартил
#
# 3 - выброс
#
# 4 - второй квартиль
#
# 5 - IQR
#
#
#
# # Практическа часть
#
# ### Задача 1
#
# Найдите лишнее.
#
# - 25-перцентиль;
# - **Q3**
# - 25% данных меньше или равны этому значению;
# - 0.25-квантиль;
# - 75% наблюдений расположены правее этого значения.
#
# ### Задача 2
# В маркетинге есть понятие ключевых потребителей. Ключевыми называют наиболее активных потребителей — тех, которые пользуются услугами и покупают гораздо чаще других. Компании внимательно следят за тем, чтобы ключевые пользователи не теряли интереса.
# Маркетологи собрали данные о количестве покупок, совершённых пользователями за последнее время: 49, 30, 25, 19, 4, 7, 13, 33, 37, 47, 42, 68, 58, 72, 62, 38.
#
# Отсортируем набор данных:
# 4, 7, 13, 19, 25, 30, 33, 37, 38, 42, 47, 49, 58, 62, 68, 72.
#
# Пусть компания следит за показателями 0.9-квантиля. Найдите значение 0.9-квантиля для следующих данных:
#
# Ответ: 65
#
#
# ### Задача 3.1
#
# В компании «Русские волки» работают 24 менеджера по продажам. Каждый месяц менеджерам ставят KPI — план продаж. В конце месяца руководитель считает разницу между KPI и фактическими продажами, то есть определяет отклонение от плана для каждого сотрудника. Если менеджер продал больше, то отклонение получается положительным. Если сотрудник недовыполнил план, то отклонение отрицательно.
# За последний месяц получились такие отклонения от KPI: −40, −24, −15, −13, −9, −6, −5, −3, −1, 0, 3, 5, 9, 11, 12, 13, 13, 14, 15, 18, 22, 25, 31, 33.
# Руководителя интересуют сотрудники, которые сильно отличились от остальных. Помогите ему провести анализ.
# Вычислите первый и третий квартиль.
#
# Ответ: -6 14
#
#
# ### Задача 3.2
#
# Рассчитайте межквартильный размах для данных из предыдущего пункта.
#
# Ответ: 20
#
# ### Задача 3.3
#
# По предыдущим расчётам определите границы выбросов.
# В ответ введите два числа через пробел: сначала нижнюю границу, затем верхнюю.
#
# Ответ: -36 и 44
#
# ### Задача 3.4
#
# Посчитайте количество выбросов в данных.
#
# Ответ: 1
#
# ### Задача 4
#
# Компания «Всем газон» планирует участвовать в научной конференции, посвящённой перспективным разработкам в сфере газонов. Ведущий селекционер хочет рассказать о расходе газонной травы, которую выводит компания. Расход газонной травы — масса семян, которые необходимо высадить на 1 квадратный метр. Обычно измеряется в г/кв. м.
# Аналитик подготовил график и пояснительную инструкцию, но часть слов стёрлись. Восстановите пропущенные слова и помогите селекционеру разобраться с графиком.
#
# - Оранжевая линия иллюстрирует A.
# - B показывает C размах.
# - D ограничивают диапазон значений, которые не очень далеко отклоняются E.
# - F — это наблюдения, сильно отличающиеся от остальных. Здесь их G.
#
# Сопоставьте букву со словом, которое должно стоять на её месте.
#
# ![Описание изображения](https://sun9-53.userapi.com/impg/yYN-LyzEwnXpg_y9qCGWvGfbjqk-yNkg5NFAPw/4aRW9K-HZp0.jpg?size=756x766&quality=95&sign=6d97a072105e574e197da0fa789b39d8&type=album)
