# %% [markdown]
# # Упражнение 1
#
# Аналитик интернет-магазина подарков «Ненужная прелесть» собрал данные по покупателям за март и построил по ним гистограмму.
#
# Проанализируйте график и выберите все верные утверждения.
#
# ![Описание изображения](https://pictures.s3.yandex.net/resources/7_1696146421.png)
#
# - **Большее количество пользователей делают небольшие покупки — до 1000 рублей.**
# - 7 покупателей потратили за март от 1500 до 2000 рублей.
# - **Покупателей, потративших 2500−3000, больше, чем покупателей, потративших 3000−3500.**
# - **Есть небольшая часть пользователей, которые совершают довольно крупные покупки: более 4000 рублей.**
#
# # Упражнение 2.1
#
# Василий ведёт трекер полезных привычек в приложении. Новая привычка — пить достаточное количество чистой воды. Василий ежедневно записывает количество, а в конце недели приложение анализирует данные. Если среднее количество выпитой воды лежит в диапазоне 2.0−2.2 литра в день, программа засчитывает неделю как удачную и даёт пользователю звёздочку.
# Данные, которые записал Василий:
#
# | День | Количество выпитой воды, л |
# |------|----------------------------|
# | 1    |    1.7                     |
# | 2    |    1.9                     |
# | 3    |    2.4                     |
# | 4    |    1.5                     |
# | 5    |    2.3                     |
# | 6    |    2.5                     |
# | 7    |    2.1                     |
#
#
# Получит ли Василий звёздочку за эту неделю?
#
# - нет, Василий в среднем пьёт меньше нужного количества
# - нет, Василий в среднем пьёт слишком много воды
# - **да, получит**
# - нельзя определить
#
# # Упражнение 2.2
#
# На фабрике производят ещё ириски «Лисп-лисп». Возьмём выборку из 100 таких ирисок и измерим в них содержание сахара:
#
# | Количество сахара (г) | Количество ирисок «Лисп-лисп» |
# |------------------------|-------------------------------|
# | 2                      | 1                             |
# | 3                      | 5                             |
# | 4                      | 14                            |
# | 5                      | 27                            |
# | 6                      | 33                            |
# | 7                      | 20                            |
#
# Вычислите среднее содержание сахара в наборе ирисок «Лисп-лисп».
#
# Ответ: 5.46

# %% [markdown]
# # Задача 1
#
# Определите тип данных и разнесите их по соответствующим корзинкам.
# ![Описание изображения](https://sun9-75.userapi.com/impg/j78LLgMbTGe_6kcmxpkKCYv6l3kypGarz4AtpA/i86kIIAUX6U.jpg?size=957x645&quality=95&sign=f4bf61ee22529f3580a89fb8de4e52bb&type=album)
#
# # Задача 2
#
# После того как фермер Владимир рассчитал среднюю урожайность яблонь в своём саду, его друзья тоже заинтересовались анализом хозяйств. Фермеры собрали информацию по деревьям, построили гистограммы и рассчитали среднее. Расставьте фермерские хозяйства в порядке возрастания средней урожайности деревьев.
#
# ![Описание изображения](https://pictures.s3.yandex.net/resources/mean_15_1685285446.png)
#
# Ответ: Доброслав < Олег < Аннушка < Владимир
#
# # Задача 3.1
#
# Спортсмен Яблочко готовится бежать кросс и ежедневно тренируется. Тренер свёл информацию о его тренировках в таблицу.
#
# | День | Километраж |
# |------|------------|
# | 1    | 7          |
# | 2    | 8          |
# | 3    | 8          |
# | 4    | 9          |
# | 5    | 9          |
# | 6    | 8          |
# | 7    | 9          |
# | 8    | 10         |
# | 9    | 10         |
# | 10   | 9          |
#
# Рассчитайте среднюю дистанцию, которую пробегает во время тренировки Яблочко. Выберите один верный вариант ответа.
#
# - **8.7**
# - 7
# - 10
# - 8.5
#
# # Задача 3.2
#
# Легкоатлет Шахматист тоже готовится к кроссу. Информация о его тренировках в таблице.
#
# | День | Километраж |
# |------|------------|
# | 1    | 10         |
# | 2    | 5          |
# | 3    | 8          |
# | 4    | 8          |
# | 5    | 25         |
# | 6    | 5          |
# | 7    | 5          |
# | 8    | 8          |
# | 9    | 8          |
#
# Рассчитайте среднюю дистанцию, которую пробегает во время тренировки Шахматист. Выберите один верный вариант ответа.
#
# - 8.5
# - **9.1**
# - 8
# - 7.2
#
# # Задача 3.3
#
# Выберите верные утверждения о тренировках спортсменов. Отметьте все верные варианты.
#
# - **У Яблочка было больше тренировок, чем у Шахматиста.**
# - В среднем Шахматист пробегает меньшую дистанцию во время тренировки, чем Яблочко.
# - Яблочко бегает на более длинные дистанции, чем Шахматист.
# - **Некорректно сравнивать средние дистанции по сделанным расчётам.**
# - **За все тренировки Яблочко пробежал большую дистанцию, чем Шахматист.**
