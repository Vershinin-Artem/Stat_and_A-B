# %% [markdown]
# ### Упражнение 2
#
# В опросе участники отвечали ещё и на вопрос: «Когда вы чаще всего едите пряники?». В качестве ответа они выбирали часы дня.
# Бинаризуем числовую переменную «часы дня». Она имеет чёткие границы (от 0 до 24), для неё естественно разбиение на интервалы одинаковой длины.
#
# ![Описание изображения](https://pictures.s3.yandex.net/resources/time_score_1_1685966258.png)
#
# Какую длину интервала вы бы выбрали для бинаризации:
#
# - 1 час
# - 3 часа
# - **6 часов**
# - 12 часов
#
# ### Упражнение 3
#
# Длина интервала в 6 часов кажется удобным вариантом, так как она не очень мелко, но и не очень крупно разбивает данные. Такое разбиение соответствует естественному пониманию дня: первые шесть часов суток — это ночь, затем утро, день и вечер. После разбиения становится заметно, что есть одна группа, которая несколько отделяется от остальных, — в районе 6−12 часов.
#
# ![Описание изображения](https://pictures.s3.yandex.net/resources/time_score_2_1685966281.png)
#
# ![Описание изображения](https://pictures.s3.yandex.net/resources/time_score_3_1685966314.png)
#
# Какой вывод можно сделать?
# Выберите один правильный вариант ответа.
#
# - Все группы ставят примерно одинаковые оценки
# - Люди, которые рано просыпаются, очень хорошо отреагировали на шоколадные пряники
# - Люди, которые едят пряники днём, более склонны к высоким оценкам, чем те, которые едят пряники вечером
# - **Те, кто поставил высокие оценки, чаще всего едят пряники по утрам**
#
# # Практическая часть
#
# ### Задача 1
#
# В уроке мы рассматривали две диаграммы: столбчатую и ящик с усами. Выберите все варианты, когда для визуализации данных больше подойдёт диаграмма «ящик с усами»:
#
# - **Нужно сравнить результаты тестов учеников в разных классах**
# - Нужно сравнить средние продажи товаров в разных магазинах
# - **Нужно проанализировать данные об уровне удовлетворённости клиентов разных возрастных групп после использования продукта**
# - Есть данные о температуре воздуха в разных городах за месяц. Нужно сравнить среднюю температуру в каждом городе
#
# ### Задача 2
#
# Рассмотрим данные, которые отражают время ожидания клиентов на обслуживание в двух разных отделениях банка в минутах.
#
# Время ожидания в южном отделении, мин: 4.7, 4.8, 4.9, 5.0, 5.0, 5.1, 5.1, 5.2, 5.2, 5.3.
# Время ожидания в северном отделении, мин: 1.5, 2.0, 3.0, 4.5, 5.0, 5.5, 6.0, 7.0, 8.0, 8.5.
# Построим ящик с усами для данных по каждому отделению:
#
# ![Описание изображения](https://pictures.s3.yandex.net/resources/boxplot_time_1685966517.png)
#
# Проанализируйте график и отметьте все верные утверждения:
#
# - Медианы значительно отличаются друг от друга
# - **Разброс значений для северного отделения больше**
# - На графике можно заметить выбросы
# - **Длина усов для северного отделения больше**
# - IQR для южного отделения равен 3
#
#
# ### Задача 3
#
# Социологи провели исследование уровня счастья в разных странах. Чтобы определить индекс счастья, специалисты спрашивали жителей страны, насколько они довольны жизнью. Учёные сравнивали результаты по странам, а также анализировали взаимосвязи между уровнем счастья жителей и другими показателями.
# На графике приведены данные по уровню коррупции и индексу счастья за 2015 год. Каждая точка соответствует отдельной стране.
# Прочитать подробнее о датасете и скачать его можно в материале на kaggle.com
#
# ![Описание изображения](https://pictures.s3.yandex.net/resources/corruption_1685966716.png)
#
# Проанализируйте диаграмму рассеивания и определите стратегию, которую стоит использовать для бинаризации. Выберите один наиболее подходящий вариант.
#
# - Вручную
#
# - Интервалы одинаковой длины
#
# - **Интервалы с одинаковым количеством наблюдений**
#
# ### Задача 4.1
#
# На графике приведены данные по стоимости автомобиля и пробегу:
#
# ![Описание изображения](https://pictures.s3.yandex.net/resources/car_1_1685966774.png)
#
# Отношение между величинами почти монотонное и данные равномерно распределены по обеим осям. Поэтому в этом случае все стратегии бинаризации дадут примерно одинаковые результаты.
#
# Для простоты давайте используем деление данных на два интервала по пробегу. В качестве границы возьмём пробег в 90 тыс. км. Получим группы с такими значениями по стоимости:
#
# Пробег <90 тыс. км: 23, 30, 33, 34, 34, 34, 35, 37, 39, 41, 41, 44, 45, 45, 45, 47, 48, 50, 52, 55.
#
# Пробег ⩾90 тыс. км: 1, 2, 8, 11, 11, 13, 14,15, 17, 18, 21, 23, 23, 26, 26, 28, 29, 33, 39, 47.
#
# Постройте по данным диаграмму «ящик с усами».
#
# ![Описание изображения](https://pictures.s3.yandex.net/resources/car_2_1685967003.png)
#
# ### Задача 4.2
#
# Проанализируйте построенную диаграмму и выберите все верные утверждения.
#
# - **90 тыс. км, стоимость автомобилей в среднем выше**
# - **В группе автомобилей с пробегом, большим или равным 90 тыс. км, стоимость автомобилей варьируется сильнее**
# - Все автомобили с пробегом, большим или равным 90 тыс. км, стоят дешевле, чем автомобили с пробегом меньше 90 тыс. км
# - В группе автомобилей с пробегом, меньшим 90 тыс. км, есть выбросы в стоимости автомобилей.
