# %% [markdown]
# ### Упражнение 1
#
# Отметьте все варианты, когда случайная величина является непрерывной:
#
# - Количество людей, ожидающих автобус на остановке
# - Оценка на экзамене
# - **Время, которое потребуется для завершения марафона**
# - Количество страниц в книге
# - **Рост маленькой зебры**
# - **Глубина озера**
# - Число голов в футбольном матче
# - Температура воздуха в Арктике
#
# ### Упражнение 2
#
# Потренируйтесь визуально определять, в каком случае площадь под графиком (закрашенная область) больше. Расставьте значения в порядке возрастания площади под функцией для заданных интервалов: от меньшего к большему.
#
# ![Описание изображения](https://pictures.s3.yandex.net/resources/2_1687958025.png)
#
# Ответ: 3 > 2 > 4 > 1
#
# ### Упражнение 3
#
# Для каждого графика подберите параметры нормального распределения, которые его описывают.
#
# ![Описание изображения](https://pictures.s3.yandex.net/resources/t_1_1686045936.png)
#
# Ответ: μ = −4, σ = 0.5
#
# ![Описание изображения](https://pictures.s3.yandex.net/resources/t_2_1686045974.png)
#
# Ответ: μ = 3, σ = 1
#
# ![Описание изображения](https://pictures.s3.yandex.net/resources/t_3_1686046001.png)
#
# Ответ: μ = −4, σ = 1
#
# ![Описание изображения](https://pictures.s3.yandex.net/resources/t_4_1686046027.png)
#
# Ответ: μ = 3, σ = 0.5
#
# ### Упражнение 4
#
# Предположим, что случайная величина имеет нормальное распределение с параметрами μ = 12, σ = 3. Выберите все варианты, когда при использовании указанного интервала можно определить, что значение 16 является выбросом.
#
# - **μ ± σ**
# - μ ± 2 ⋅ σ
# - μ ± 3 ⋅ σ
#
# ### Упражнение 5
#
# Если случайная величина X имеет нормальное распределение с параметрами μ = 12, σ = 3, найдите z-оценку для значения x = 9.
#
# Ответ: -1
#
# # Практическая часть
#
# ### Задача 1
#
# Соотнесите случайную величину и её тип:
#
# ![Описание изображения](https://sun9-60.userapi.com/impg/OF_f4gvTa31jlKLwv32z1yuMgZnmNb_DBqh9eg/2dvCNAmqIiw.jpg?size=642x639&quality=95&sign=65162d9573e113c81daa30bb082afe6a&type=album)
#
# ### Задача 2
#
# Выберите график, который отражает наибольшую вероятность получить значения из указанного интервала:
#
# ![Описание изображения](https://pictures.s3.yandex.net/resources/task_2_1686049156.png)
#
# Ответ: 1
#
# ### Задача 3
#
# Давайте возьмём случайную величину «время, которое требуется домашнему коту для того, чтобы принять решение выйти на улицу или остаться дома, когда дверь открыта» (для сокращения записи будем использовать X). Предположим, что она имеет нормальное распределение с параметрами μ = 20 секунд, σ = 5 секунд. Вы проводите исследование и каждый день записываете соответствующее время. Используйте правило двух сигм, чтобы определить, в какие из дней кот нарушал свои привычки.
#
# | День | 1  | 2  | 3  | 4  | 5  |
# |------|----|----|----|----|----|
# | x    | 19 | 7  | 11 | 27 | 31 |
#
#
# Ответ: день 2 и день 5
#
# ### Задача 4
#
# Вы одолжили кота у своего друга и проводите похожее исследование. Ваш друг заявил, что для его кота правильно будет использовать параметры μ = 30 и σ
# = 3.Используйте стандартизацию и отметьте все значения, которые не попадают в интервал для 95% наиболее вероятных значений.
#
# | День | 1  | 2  | 3  | 4  | 5  |
# |------|----|----|----|----|----|
# | x    | 31 | 27 | 29 | 23 | 30 |
#
# Ответ: День 4
