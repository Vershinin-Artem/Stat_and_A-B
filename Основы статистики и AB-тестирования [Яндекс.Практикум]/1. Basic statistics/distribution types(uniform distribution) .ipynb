# %% [markdown]
# ### Упражнение 1
#
# Разнесите высказывания по правильным корзинкам.
#
# ![Описание изображения](https://sun9-57.userapi.com/impg/WcHp0XtVGSQ_mcK3P5AixJt0LcnewyGiHwsyrg/arKWBxzIl9s.jpg?size=657x488&quality=95&sign=80e5b9d88df233251b18ee928b517f41&type=album)
#
# ### Упражнение 2
#
# В отделе аналитики IT-компании «Шмугл» развёрнута система проведения исследований. Все пользователи случайным образом разбиты на группы под номерами от
# 0 до 99. Это позволяет проводить много исследований одновременно и независимо друг от друга.
# Аналитики компании берут пользователей из определённой группы и изучают влияние различных изменений системы на поведение человека. Эти изменения происходят одновременно и не зависят друг от друга. Равномерность и случайность процесса разбиения пользователей гарантируют репрезентативность.
# Есть подозрение, что пользователей в нескольких группах гораздо больше, чем должно быть. Рассчитайте теоретическое значение вероятности, с которой каждый пользователь должен попасть в конкретную группу.
# В ответ введите число, при необходимости округлите результат до сотых, дробную часть отделите точкой.
#
# Ответ: 0.01
#
# ### Упражнение 3
#
# На новогоднем корпоративе руководитель компании устроил лотерею. Каждый сотрудник получил билет с номером от 100 до 999. В конце мероприятия случайным образом выбирался один билет из всех. Найдите вероятность того, что выигрышным окажется билет, номер которого не превышает значение 170.
# В ответ введите число, при необходимости округлите результат до сотых, дробную часть отделите точкой.
#
# Ответ: 0.08
#
# ### Упражнение 4
#
# Популярный пример использования равномерного распределения — эксперименты с игральным кубиком. Представьте кубик, у которого 18 граней, а значения от
# 1 до 18 выпадают с равной вероятностью. Найдите математическое ожидание для числа, которое выпадет на таком кубике. В ответ введите число, при необходимости округлите результат до сотых, дробную часть отделите точкой.
#
# Ответ: 9.5
#
#
# ### Упражнение 5
#
# Предположим, что вы купили новую соковыжималку, но ваша собака съела инструкцию. Сколько апельсинов нужно на один литр сока — неизвестно, но вы оцениваете, что это количество должно составлять от 5 до 15 штук. Используя равномерное распределение, определите дисперсию такой случайной величины.
#
# Ответ: 10
#
#
# # Практическая часть
#
# ### Задача 1
#
# Выберите все верные утверждения.
#
# - **Теоретический подход использует некоторую модель для получения полного представления о данных**
# - Теоретический подход основывается на оценке вероятностей, исходя из имеющихся данных
# - **Эмпирический подход основывается на оценке вероятностей, исходя из имеющихся данных**
# - Эмпирический подход использует модели с небольшим количеством параметров для анализа данных
# - Теоретический подход всегда лучше эмпирического, потому что он основан на научных моделях
# - **Использование теоретической модели в статистике может упростить работу, так как определяется небольшим числом параметров**
#
#
# ### Задача 2
#
# Вы решили открыть сервис по прогнозу погоды «Угадайка». Всё шло хорошо, пока не оказалось, что для одной северной столицы сложно научиться предсказывать количество ясных дней в году. Так, вам предлагается использовать равномерное распределение с параметрами a = 10, b = 130.
#
# Ответ: P(X=x) = 1/121
#
# ### Задача 3
#
# Продолжаем анализировать тот же кейс. В прошлом году было целых 96 солнечных дней, что является наилучшим результатом за последние 15 лет. Найдите вероятность того, что в следующем году это количество будет ещё больше. В ответ введите число, при необходимости округлите результат до сотых, дробную часть отделите точкой.
#
# Ответ: 0.28
#
# ### Задача 4
#
# Напомним: вам предлагается использовать равномерное распределение с параметрами a = 10, b = 130. Посчитайте математическое ожидание для данной случайной величины.
#
# Ответ: 70
#
# ### Задача 5
#
# Посчитайте дисперсию для данной случайной величины, учитывая, что у вас есть равномерное распределение с параметрами a = 10, b = 130.
#
# Ответ: 1220
