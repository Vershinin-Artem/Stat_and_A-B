# %% [markdown]
#
# ### Упражнение 1
#
# Рассчитайте дисперсию для массы конфет подмастерья. В ответ введите число.
#
# | i | 1   | 2   | 3   | 4   | 5   |
# |---|-----|-----|-----|-----|-----|
# | (mi - m̄)²  | 100 | 9   | 9   | 9   | 49  |
#
# Ответ: 44
#
# ### Упражнение 2
#
# Посчитайте стандартное отклонение для массы конфет подмастерья. В ответ введите число, округлите до сотых.
#
# Ответ: 6.63
#
# ### Упражнение 3
#
# Даны гистограммы зарплат сотрудников по цехам кондитерской фабрики. Проанализируйте графики и расставьте величины в порядке возрастания разброса.
#
# ![Описание изображения](https://pictures.s3.yandex.net/resources/PPROD-8816_1739448735.png)
#
# Ответ: транспорт < производство < маркетинг < администрация
#
# # Практическая часть
#
# ### Задача 1.1
# Как выбрать лучший город с точки зрения погоды? Кто-то хочет больше снега, кто-то — больше солнца, а аналитики — стабильности. Универсальным показателем погоды считают температуру.
# Городом для сравнения возьмём Москву. В таблице представлены данные по средней температуре каждого месяца.
# Раньше мы такую таблицу строили горизонтально, но сейчас она получается слишком широкой, так что мы перевернули и построили её вертикально.
#
# ![Описание изображения](https://sun9-48.userapi.com/impg/IbCzibNJ_obKoaHhQYQp-4iB8StZhB4l2ClccQ/oXdAayLYGio.jpg?size=707x615&quality=95&sign=ff220dc9b8e08185b6c61f6f3da6d896&type=album)
#
# Посчитайте дисперсию.
# Результат округлите до сотых. В поле ответа введите число.
#
# Ответ:  119.27
#
# ### Задача 1.2
#
# Посчитайте стандартное отклонение и введите ответ в виде числа. Ответ округлите до сотых.
# Ваш ответ правильный
#
# Ответ: 10.92
#
# ### Задача 2
# Определите, какое описание соответствует каждому графику. Учитывайте характер данных, попробуйте по описанию предугадать, насколько большой будет дисперсия.
#
# ![Описание изображения](https://pictures.s3.yandex.net/resources/task_2_1_1685304455.png)
# Ответ: стоимость нового рояля
#
# ![Описание изображения](https://pictures.s3.yandex.net/resources/task_2_3_1685304492.png)
# Ответ: стоимость старинного рояля
#
# ![Описание изображения](https://pictures.s3.yandex.net/resources/task_2_2_1685304515.png)
# Ответ: стоимость поддержаного рояля
