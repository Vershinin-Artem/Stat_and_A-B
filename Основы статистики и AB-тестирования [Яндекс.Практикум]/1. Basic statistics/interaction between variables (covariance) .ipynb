# %% [markdown]
# ### Упражнение 1
#
# Вернёмся к кондитерской фабрике. Рассмотрим диаграмму рассеивания для температуры и количества брака:
#
# ![Описание изображения](https://pictures.s3.yandex.net/resources/Vizualizatsiia_kategorialnykh_i_poriadkovykh_peremennykh_82_1689696808.png)
#
#
# Что можно сказать о ковариации этих величин?
#
# Правильный ответ
#
# - **Положительна, так как при увеличении одной величины увеличивается и вторая**
# - Отрицательна, так как при увеличении одной величины вторая уменьшается
# - Равна нулю, нет явной взаимосвязи между величинами
#
# ### Упражнение 2.1
# Вычислите произведение отклонений от средних значений для измерения 4.
#
# |  i | 1  | 2  | 3  | 4  | 5  | 6  |
# |--------------|----|----|----|----|----|----|
# | tᵢ           | 21 | 27 | 24 | 19 | 22 | 25 |
# | dᵢ           | 14 | 19 | 15 | 13 | 17 | 18 |
# | tᵢ - t̄       | -2 |    |    |    |    |    |
# | dᵢ - d̄       | -2 |    |    |    |    |    |
# | (tᵢ-t̄)(dᵢ-d̄) | 4  |    |    |    |    |    |
#
# Ответ: 12
#
# ### Упражнение 2.2
#
# Вычислите произведение отклонений от средних значений для измерения 5.
#
# Ответ: 1
#
# ### Упражнение 2.3
#
# Вычислите произведение отклонений от средних значений для измерения 6.
#
# Ответ: 6
#
# ### Упражнение 3
#
# Что произойдёт с коэффициентом ковариации, если заменить количество испорченных товаров на количество денег, которые спишут в убыток? Что подсказывает вам интуиция?
#
# - **Вырастет**
# - Упадёт
# - Не изменится
#
# ### Упражнение 4
#
# Рассчитайте коэффициент ковариации между температурой и количеством денег, которые спишут в убыток. Используйте только что рассчитанную таблицу.
#
# Ответ: 600
#
# # Практическая часть
#
# ### Задача 1
#
# Есть 5 наблюдений о дневном объёме торгов двух активов: A и B. Актив A — это золото. Актив B — это акции высокорисковой компании. Объём торгов будем считать в миллионах долларов.
#
# |  | 1   | 2   | 3   | 4   | 5   |
# |----------------|-----|-----|-----|-----|-----|
# | Актив A        | 300 | 320 | 290 | 350 | 310 |
# | Актив B        | 150 | 120 | 180 | 90  | 160 |
#
# Рассчитайте коэффициент ковариации для этих величин.
#
# Ответ: -775
#
#
# Задача 2
# Дана информация о парах величин. Нарисуйте диаграммы рассеивания для каждой пары. По графикам подберите подходящее значение коэффициента ковариации.
#
# - Количество страниц в учебнике: 120, 200, 90, 300, 75, 180, 250.
# - Количество студентов, дочитавших учебник до конца: 25, 18, 30, 10, 34, 22, 12.
#
# Ответ: -733,21
#
# Продолжительность подготовки к экзамену (часы): 2, 3, 5, 6, 7, 8, 10.
# Количество решённых задач на экзамене: 2, 4, 8, 10, 11, 12, 16.
#
# Ответ: 13.33
#
# Продолжительность подготовки к экзамену (часы): 2, 3, 5, 6, 7, 8, 10.
# Количество набранных баллов: 11, 24, 34, 55, 68, 88, 100.
#
# Ответ: 91.38
#
# Количество билетов на экзамене: 5, 10, 15, 20, 25, 30, 35.
# Количество билетов, которые выучил студент: 1, 1, 1, 1, 1, 1, 1.
#
# Ответ: 0
#
# ## Задача 3
#
# Проанализируйте результаты, полученные в предыдущей задаче. Выберите все верные утверждения.
#
# - **Значение ковариации зависит от масштаба и единиц измерения величин**
#
# - Взаимосвязь между продолжительностью подготовки к экзамену и полученными баллами сильнее, чем взаимосвязь между этой продолжительностью и количеством решённых задач.
#
# - **Коэффициент ковариации величин «количество страниц в учебнике» и «количество студентов, дочитавших учебник до конца» меньше нуля. Это указывает на отрицательную взаимосвязь**
#
# - Чтобы получить хорошую оценку на экзамене, надо много учиться.
