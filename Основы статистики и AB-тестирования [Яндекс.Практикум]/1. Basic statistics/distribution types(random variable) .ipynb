# %% [markdown]
# ### Упражнение 1
#
# Определите, какие описания соответствуют принципам формулировки генеральной совокупности.
#
# - Люди, которые пользуются интернетом
# - **Все дома в городе Тригонограде, построенные в 2010−2020 годах**
# - Студенты, которые ходят на занятия по физкультуре в университете
# - Животные в зоопарке
# - Дети в возрасте от 10 лет, обучающиеся в начальной школе города Фурьенинбурга в 2022−2023 учебном году
#
# ### Упражнение 2
#
# Перенесёмся к дедушке на дачу. Он ещё в далёкой молодости установил на речке много раколовок. Это такая шина, в которой иногда поселяются раки. Если аккуратно исследовать каждую шину, то можно обнаружить какое-то количество раков и насобирать их себе на ужин. Важное замечание: раки не живут большой семьёй. Как только их становится больше пяти, они расселяются в другие шины.
# Проанализируем распределение количества раков в раколовке с помощью графика:
#
# ![Описание изображения](https://pictures.s3.yandex.net/resources/task_1685988135.png)
#
# Ответ: 0.1
#
# # Практическая часть
#
# ### Задача 1
#
# Выберите верные формулировки генеральной совокупности. Отметьте все правильные варианты.
#
# - **Все автомобили, произведённые на заводе в 2023 году, являются генеральной совокупностью, а 100 случайно отобранных автомобилей из них — выборкой**
# - Все жители города являются выборкой, а жители определённого района города — генеральной совокупностью
# - **Все пациенты больницы, проходящие лечение от определённого заболевания, являются генеральной совокупностью, а 50 случайно отобранных пациентов, которые лечатся от этого заболевания, — выборкой**
# - Все школьники одной страны — это генеральная совокупность, а школьники одной школы — это выборка
#
# ### Задача 2
#
# Соотнесите утверждения о вероятности с формулами, по которым они рассчитываются.
#
# ![Описание изображения](https://sun9-38.userapi.com/impg/3U1hgqefPtBFOAJ_qr-0_LTO9RGMzjQQYACXkw/0x_7GQ_EKi8.jpg?size=614x599&quality=95&sign=c80a7a11ec60e54fda581abb3afb1e2c&type=album)
#
# ### Задача 3
# Компания «Модные подкрадули» занимается продажей обуви онлайн. Её аналитики исследуют данные о количестве покупок, совершаемых клиентами за один визит на сайт. Они хотят узнать распределение количества купленных пар обуви на одного клиента, чтобы лучше управлять предложением и оптимизировать маркетинговые стратегии.
# Вот данные:
#
# [1, 1, 2, 3, 1, 4, 2, 1, 1, 1, 2, 1, 3],  где каждый элемент списка — это количество пар обуви, купленных одним клиентом за один визит на сайт.
# Найдите вероятность того, что клиент купит как минимум 3 пары за один визит. Ответ запишите десятичной дробью через точку.
#
# Определить значения функции вероятности для каждого количества купленных пар обуви, используя частоты из таблицы.
# Определить значения эмпирической функции распределения для каждого количества купленных пар обуви.
#
# Ответ: 0.23
