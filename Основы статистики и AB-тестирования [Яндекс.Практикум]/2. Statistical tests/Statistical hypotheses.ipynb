# %% [markdown]
# ### Упражнение 1
#
# Главный аналитик учит новичков корректно проводить анализ. Помогите ему составить текст. Вставьте пропущенные слова:
# «Пусть наша задача — оценить среднюю стоимость резиновых куриц на рынке. Рассмотрим A производителей резиновых куриц, за случайную величину возьмём среднюю B каждого производителя. Выдвигаем нулевую и альтернативные гипотезы: H0: μ=75, H1: μ ≠ 75. Здесь C резиновых куриц. Как мы действуем: сначала выбираем D производителей, затем собираем данные о стоимости их резиновых куриц, а потом применяем E для проверки гипотезы. Результаты теста позволяют учесть возможную F и сделать обоснованные выводы о генеральной совокупности».
#
# Ответ:
#
# ![Описание изображения](https://sun9-61.userapi.com/impg/jpYktQv_q0wx9JxbWUZ9gzd3ac4qX9Smq_mFJA/bbSHW7qTAOU.jpg?size=574x657&quality=95&sign=27a403ffa6cd86147453b1d8adea02ae&type=album)
#
#
# ### Упражнение 2
#
# Представим себя зоологами и исследуем массу животных. Есть предположения о средней массе разных существ и расчёты необходимых показателей. Выясните, есть ли основания отвергать гипотезу о средней массе животного. Для этого…
#
#
# 2.1 Определите, будет ли значение z-статистики попадать в зону за пределами критических значений: x = 300, μ = 309, σ = 48, n = 64.
#
# Ответ: между критическими значениями, не отвергаем H0
#
# 2.2 Определите, будет ли значение z-статистики попадать в зону за пределами критических значений: x = 60, μ = 55, σ = 20, n = 100.
#
# Ответ: за критическими занчениями, отвергаем Н0
#
# 2.3 Определите, будет ли значение z-статистики попадать в зону за пределами критических значений: x = 403, μ = 410, σ = 36, n = 225.
#
# Ответ: за критическими занчениями, отвергаем Н0
#
# 2.4 Определите, будет ли значение z-статистики попадать в зону за пределами критических значений: x = 129, μ = 125, σ = 120, n = 400.
#
# Ответ: между критическими значениями, не отвергаем H0
#
#
# # Практическая часть
#
# ### Задача 1
#
# Расставьте шаги Z-теста в верном порядке.
#
# Ответ:
#
# ![Описание изображения](https://sun9-28.userapi.com/impg/s93FgqVZszygy5u65Mpm2K0ZKPMD-KVsgqmx8g/quJOxNhHhT4.jpg?size=453x555&quality=95&sign=dc34b4c5243f357fa059d21487c6ca56&type=album)
#
# Правильный ответ:
#
# Верный порядок шагов:
# - Формулируем H0, H1
# - Выбираем α, находим соответствующие критические значения
# - Считаем выборочное среднее
# - Считаем z-статистику
# - Сравниваем z-статистику с критическими значениями
# - Принимаем решение об отклонении H0
#
#
# ### Задача 2.1
#
# Поговорим о вечной проблеме — о дорогах. По норме в асфальте должно быть 700 грамм щебня на каждый килограмм. Комиссия проводит измерения в новом асфальте, чтобы не пришлось перекладывать заново в следующем ноябре. Проверяющие берут пробу на 25 разных участках и замеряют количество щебня.
# Вот какие данные используются в исследовании:
#
# Предполагаемое среднее значение генеральной совокупности: 700
#
# Стандартное отклонение генеральной совокупности: 80
#
# Среднее значение по выборке: 660
#
# Размер выборки: 25
#
# Сформулируйте гипотезы.
#
#
# Jтвет: H0: μ = 700, H1: μ ≠ 700
#
# ### Задача 2.2
#
# Гипотезы есть, теперь зафиксируем уровень значимости α = 0.05. Что означает уровень значимости?
#
# - **Это вероятность совершения ошибки первого рода, то есть отклонить нулевую гипотезу, когда она верна.**
#
# - Это вероятность совершения ошибки первого рода, то есть отклонить нулевую гипотезу, когда она не верна.
#
# - Это ситуация, когда исследователь отвергает нулевую гипотезу, хотя она на самом деле верна.
#
# - Это ситуация, когда исследователь не отвергает нулевую гипотезу, хотя она на самом деле верна.
#
# ### Задача 2.3
#
# Рассчитайте значение z-статистики, если среднее значение по выборке равно 660, предполагаемое среднее значение генеральной совокупности равно 700, стандартное отклонение генеральной совокупности равно 80, размер выборки равен 25.
#
# Ответ: -2.5
#
# ### Задача 2.4
#
# Сделайте вывод о том, можно ли отклонить нулевую гипотезу на основе данных из предыдущей задачи. Да, можно, так как значение z-статистики отрицательное.
#
# - **Нет, нельзя, так как значение z-статистики не попало в допустимую область.**
#
# - **Да, можно, так как значение z-статистики не попало в интервал между критическими значениями.**
#
# - **Если такое происходит, у нас есть основания отклонить нулевую гипотезу.**
#
# - **Нет, нельзя, так как z-статистика больше уровня значимости.**
