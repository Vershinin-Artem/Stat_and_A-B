# %% [markdown]
# ### Упражнение 1
#
# Возьмём другую выборку такого же размера: 270, 261, 250, 233, 286.
#
# Вычислите среднее количество пятен на жирафе на основе этих данных. В ответ введите число.
#
# Ответ: 260
#
#
# ### Упражнение 2
#
# Проведём эксперимент ещё 10 раз. Получились вот такие средние значения по выборкам:
#
# | Выборка   | Значение |
# |-----------|----------|
# | Выборка 1 | 260      |
# | Выборка 2 | 255      |
# | Выборка 3 | 270      |
# | Выборка 4 | 260      |
# | Выборка 5 | 265      |
# | Выборка 6 | 270      |
# | Выборка 7 | 260      |
# | Выборка 8 | 255      |
# | Выборка 9 | 265      |
# | Выборка 10| 260      |
#
# Вычислите стандартное отклонение для этих выборочных средних. В ответ введите число, дробную часть отделите точкой, результат округлите до сотых.
#
# Посчитаем среднее:
#
# Ответ: 262
#
# А теперь стандартное отклонение:
#
# Ответ: 5.37
#
# ### Упражнение 3
#
# Допустим, что стандартное отклонение в генеральной совокупности равно 50 пятен. Вы планируете взять несколько выборок разного размера: n1 = 16, n2 = 25, n3 = 100, n4 = 64.
#
# Вычислите стандартную ошибку среднего (SE) для каждой выборки. Расположите полученные значения по возрастанию.
#
# Ответ:
#
# n3 < n4 < n2 < n1
#
# # Практическая часть
#
# ### Задача 1
#
# Экологи измерили уровень загрязнённости воздуха в 9 случайно выбранных точках города и получили следующие значения (в микрограммах на кубический метр):
# 46, 37, 51, 47, 42, 39, 43, 46, 45.
#
# Вычислите среднюю концентрацию загрязнителей в воздухе на основе этих данных. В ответ введите число.
#
# Ответ: 44
#
# ### Задача 2
#
# Вот что было с этими точками в предыдущие годы: согласно наблюдениям Гидрометцентра, стандартное отклонение в генеральной совокупности равнялось 5.
#
# Вычислите стандартную ошибку среднего.
# В ответ введите число, при необходимости округлите результат до сотых, дробную часть отделите точкой.
#
# Ответ: 1.67
#
# ### Задача 3
#
# На основе полученных данных из прошлых задач, где измерялся уровень загрязнённости воздуха (в микрограммах на кубический метр): 46, 37, 51, 47, 42, 39, 43, 46, 45, а среднее равно 44, вычислите стандартное отклонение для этой выборки.
# В ответ введите число, при необходимости округлите результат до сотых, дробную часть отделите точкой.
#
# Ответ: 4.27
